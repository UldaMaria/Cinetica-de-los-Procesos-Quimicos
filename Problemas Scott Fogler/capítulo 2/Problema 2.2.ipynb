# %% [markdown]
# # Problema 2.2
#  ### Determinación del tamaño de un CSTR
# "Elementos de Ingeniería de las reacciones químicas" ,Scott Fogler capitulo 1, página 48
#
# ![newnotebook](../imágenes/problema2.2.png)

# %% [markdown]
# <font color="brown">**Primero insertaremos todos los paquetes y librerías que nos serán útiles para el desarrollo del ejercicios, es necesario que actives la celda dede un pricipio de lo contrario puede pasar que no se interprete el código y marque error.**</font>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# %%
# Datos
X = np.array([0.0, 0.1, 0.2, 0.4, 0.6, 0.7, 0.8])
Fao_rA = np.array([0.89, 1.08, 1.33, 2.05, 3.54, 5.06, 8.0])
print(Fao_rA)
# Out:
# [0.89 1.08 1.33 2.05 3.54 5.06 8.  ]

# %%
# Plot
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
ax1.minorticks_on()
ax1.set_xlabel('$Conversión, \\ X$')
ax1.set_ylabel('$\\frac{F_{A0}}{-r_A} \\ \\left( m^3 \\right)$')
ax1.set_title('Gráfica de Levenspiel PFR \n'
              + '$V_{CSTR} =$' + '6400 $dm^3$')
ax1.plot(X, Fao_rA, marker='o')
ax1.grid(which='BOTH', ls=':')
ax1.grid(True)
ax1.add_patch(Rectangle(xy=(0.0, 0.0), width=0.8, height=8.0,
                        alpha=1, facecolor='moccasin',
                        fill=True, edgecolor='peru', hatch="/"))
plt.show()
